# %%
'''1. Выберите свой любимый вид спорта и создайте список с именами выдающихся спортсменов.
Используйте свой список для вывода утверждений об элементах пример: «Я хотел бы сыграть с Gerrard».
Вывод:
«Я хотел бы сыграть с Gerrard»
«Я хотел бы сыграть с Ronaldo»
«Я хотел бы сыграть с Messi»'''

list = ['Magnus', 'S1mple', 'Tont']
for i in list:
    print('Я хотел бы сыграть с',i)
# Out:
# Я хотел бы сыграть с Magnus
# Я хотел бы сыграть с S1mple
# Я хотел бы сыграть с Tont

# %%
'''2. Создайте список гостей, включающий минимум трех людей, которых вам хотелось бы пригласить на обед.
Затем используйте этот список для вывода пригласительного сообщения каждому участнику используя f’формат.
Вывод:
«Приглашаю тебя, Кайрат, на обед»
«Приглашаю тебя, Айжан, на обед»
«Приглашаю тебя, Айдын, на обед»'''

guests = ['Айгуль','Айбек','Арман']
for i in guests:
    print(f"Приглашаю тебя, {i}, на обед")
# Out:
# Приглашаю тебя, Айгуль, на обед
# Приглашаю тебя, Айбек, на обед
# Приглашаю тебя, Арман, на обед

# %%
'''3. Представим, что вы решили купить обеденный стол большего размера.
Дополнительные места позволяют пригласить на обед еще трех гостей.
Добавьте в конец программы команду print, которая выводит сообщение о расширении списка гостей.
Вывод:
«Расширяем список гостей»
- Добавьте вызов insert() для добавления одного гостя в начало списка.
- Добавьте вызов insert() для добавления одного гостя в середину списка.
- Добавьте вызов append() для добавления одного гостя в конец списка.
- Выведите новый набор сообщений с приглашениями — по одному для каждого участника, входящего в список.
Вывод:
«Приглашаю тебя, Арман, на обед»
«Приглашаю тебя, Кайрат, на обед»
«Приглашаю тебя, Канат, на обед»
«Приглашаю тебя, Айжан, на обед»
«Приглашаю тебя, Айдын, на обед»
«Приглашаю тебя, Айтолкын, на обед»'''

guests = ['Айгуль','Айбек','Арман']
guests.insert(0,'Айнур')
guests.insert(len(guests)//2,'Сергазы')
guests.append('Ғалымбек')
for i in guests:
    print(f"Приглашаю тебя, {i}, на обед")

print(guests)
# Out:
# Приглашаю тебя, Айнур, на обед
# Приглашаю тебя, Айгуль, на обед
# Приглашаю тебя, Сергазы, на обед
# Приглашаю тебя, Айбек, на обед
# Приглашаю тебя, Арман, на обед
# Приглашаю тебя, Ғалымбек, на обед
# ['Айнур', 'Айгуль', 'Сергазы', 'Айбек', 'Арман', 'Ғалымбек']

# %%
'''4. Выяснилось, что новый обеденный стол привезти вовремя не успеют и места хватит только для двух гостей.
Добавьте команду для вывода сообщения о том, что на обед приглашаются всего два гостя.
Вывод:
«Уменьшаем список гостей»
- Используйте метод pop() для последовательного удаления гостей из списка до тех пор, пока в списке не останутся только два человека.
- Каждый раз, когда из списка удаляется очередное имя, выведите имя этого человека и сообщение о том, что вы сожалеете об отмене приглашения.
Вывод:
«Сожалею об отмене приглашения, Айтолкын, на обед»
«Сожалею об отмене приглашения, Айдын, на обед»
«Сожалею об отмене приглашения, Канат, на обед»
«Сожалею об отмене приглашения, Айжан, на обед»'''


while len(guests)>2:
    i = len(guests)-1
    x = guests.pop(i)
    print(f"Сожалею об отмене приглашения, {x}, на обед")
print(guests)
# Out:
# Сожалею об отмене приглашения, Ғалымбек, на обед
# Сожалею об отмене приглашения, Арман, на обед
# Сожалею об отмене приглашения, Айбек, на обед
# Сожалею об отмене приглашения, Сергазы, на обед
# ['Айнур', 'Айгуль']

# %%
'''5. Вспомните хотя бы пять стран, в которых вам хотелось бы побывать.
- Сохраните названия стран в списке. Проследите за тем, чтобы список не хранился в алфавитном порядке.
- Выведите список в исходном порядке.
- Используйте функцию sorted() для вывода списка в алфавитном порядке без изменения списка.
- Снова выведите список, чтобы показать, что он по-прежнему хранится в исходном порядке.
- Измените порядок элементов вызовом reverse().
- Выведите список, чтобы показать, что элементы следуют в другом порядке.'''

countries = []
countries.append('Switzerland')
countries.append('Russia')
countries.append('Italy')
countries.append('USA')
countries.append('Japan')
print(countries)
print(sorted(countries, reverse = False))
print(countries)
countries.reverse()
print(countries)
# Out:
# ['Switzerland', 'Russia', 'Italy', 'USA', 'Japan']
# ['Italy', 'Japan', 'Russia', 'Switzerland', 'USA']
# ['Switzerland', 'Russia', 'Italy', 'USA', 'Japan']
# ['Japan', 'USA', 'Italy', 'Russia', 'Switzerland']
